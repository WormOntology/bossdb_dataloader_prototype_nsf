# %% [markdown]
# # Test Load from BossDB
#
# Here is some test WormAtlas data: https://bossdb.org/project/white1986

# %%
from intern import array
import matplotlib.pyplot as plt
import numpy as np

# %%
# Channel for test data
channel = array("bossdb://white1986/n2u/em")
# get middle of test data's cube
data = channel[143:159, 3661:4685, 5903:6927] # (ZYX order)

# %%
# show example slice
plt.imshow(data[10]);

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(10,10))

ax.imshow(data[0], cmap='gray')
